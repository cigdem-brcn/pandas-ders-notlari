# %%
import pandas as pd
import numpy as np

# %%
obje = pd.Series(np.arange(5), index = ["a","b","c","d","e"])
obje
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
obje.c
# Out:
# np.int64(2)

# %%
obje["c"]
# Out:
# np.int64(2)

# %%
obje[:3]
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obje[::2]
# Out:
# a    0
# c    2
# e    4
# dtype: int64

# %%
obje[["a","c"]]
# Out:
# a    0
# c    2
# dtype: int64

# %%
obje[obje<2]
# Out:
# a    0
# b    1
# dtype: int64

# %%
obje["a":"c"]   #including final value
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obje["b":"c"]=5
obje
# Out:
# a    0
# b    5
# c    5
# d    3
# e    4
# dtype: int64

# %%
data = pd.DataFrame(np.arange(16).reshape(4,4),
                    index=["bursa","ankara","rize","istanbul"],
                    columns=["one","two","three","four"])
data
# Out:
#           one  two  three  four
# bursa       0    1      2     3
# ankara      4    5      6     7
# rize        8    9     10    11
# istanbul   12   13     14    15

# %%
data[["one","three"]]
# Out:
#           one  three
# bursa       0      2
# ankara      4      6
# rize        8     10
# istanbul   12     14

# %%
data[:3]   #final index not included
# Out:
#         one  two  three  four
# bursa     0    1      2     3
# ankara    4    5      6     7
# rize      8    9     10    11

# %%
data[data["four"]>5]
# Out:
#           one  two  three  four
# ankara      4    5      6     7
# rize        8    9     10    11
# istanbul   12   13     14    15

# %%
#iloc for numbers
#loc for tags

# %%
data.iloc[1]  # index 1
# Out:
# one      4
# two      5
# three    6
# four     7
# Name: ankara, dtype: int64

# %%
data.iloc[1,[1,2,3]]  #index 1, column 1,2,3
# Out:
# two      5
# three    6
# four     7
# Name: ankara, dtype: int64

# %%
data.iloc[[1,3],[1,2,3]]
# Out:
#           two  three  four
# ankara      5      6     7
# istanbul   13     14    15

# %%
data.loc["rize", ["one","two"]]
# Out:
# one    8
# two    9
# Name: rize, dtype: int64

# %%
data.loc[:"rize","four"]
# Out:
# bursa      3
# ankara     7
# rize      11
# Name: four, dtype: int64

# %%
#important methods

# %%
data2 = data.reindex(["rize","istanbul","bursa","ankara","nigde"])
data2
# Out:
#            one   two  three  four
# rize       8.0   9.0   10.0  11.0
# istanbul  12.0  13.0   14.0  15.0
# bursa      0.0   1.0    2.0   3.0
# ankara     4.0   5.0    6.0   7.0
# nigde      NaN   NaN    NaN   NaN

# %%
number = ["four", "one", "five"]
data.reindex(columns=number)
# Out:
#           four  one  five
# bursa        3    0   NaN
# ankara       7    4   NaN
# rize        11    8   NaN
# istanbul    15   12   NaN

# %%
s = pd.Series(["blue", "red", "pink"], index=[0,2,3])
s
# Out:
# 0    blue
# 2     red
# 3    pink
# dtype: object

# %%
s.reindex(range(6), method = "ffill")
# Out:
# 0    blue
# 1    blue
# 2     red
# 3    pink
# 4    pink
# 5    pink
# dtype: object

# %%
new_s = s.drop(2)
new_s
# Out:
# 0    blue
# 3    pink
# dtype: object

# %%
s.drop([0,3])
# Out:
# 2    red
# dtype: object

# %%
data3 = pd.DataFrame(np.arange(16).reshape(4,4), 
                     index = ["ali" ,"efe", "can", "nur"],
                     columns = list("ABCD"))
data3
# Out:
#       A   B   C   D
# ali   0   1   2   3
# efe   4   5   6   7
# can   8   9  10  11
# nur  12  13  14  15

# %%
data3.drop(["ali", "efe"])
# Out:
#       A   B   C   D
# can   8   9  10  11
# nur  12  13  14  15

# %%
# axis = 1  or axis="index"    To delete a column
# axis = 0  or axis="columns"  To delete a row

# %%
data3.drop("A",axis=1)
# Out:
#       B   C   D
# ali   1   2   3
# efe   5   6   7
# can   9  10  11
# nur  13  14  15

# %%
data3.drop("ali",axis=0)
# Out:
#       A   B   C   D
# efe   4   5   6   7
# can   8   9  10  11
# nur  12  13  14  15

# %%
data3.mean()
# Out:
# A    6.0
# B    7.0
# C    8.0
# D    9.0
# dtype: float64

# %%
data3.mean(axis="columns")
# Out:
# ali     1.5
# efe     5.5
# can     9.5
# nur    13.5
# dtype: float64
